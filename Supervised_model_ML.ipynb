# %% [markdown]
# #Linear Regression:-
#
# - used to predict a continuous value by finding the releationship between input,output feature.
#  - linear regression equation:- y=mx+b
#
#  -Import Libraries --> Load Dataset --> Encoding--> Separate Input & Output -->Train Test Split --> Train Model --> Prediction --> Performance Evaluation

# %%
#Train model
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(x_train,y_train)

#Predict

y_pred = lr.predict(x_test)


#Performance Evaluation
from sklearn.metrics import r2_score

r2_score(y_test,y_pred)

# %% [markdown]
# # Logistic Regression :-
# - used for classification problems,mainly for predicting yes/no ,true/false or 1/0 output.
# - it is use amathematicaly regression equation to calculate probability.but the find output is converted into classes using the Sigmoid function.
#
# - Internally Activatio fuction --> sigmoid activation function --> Classes or sub-categories--> problability

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)

#Predict
y_pred=lr.predict(X_test)

#Performance Evaluation
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
